# %%
# %pip install pandas
# %pip install pandas-profiling
# %pip install --upgrade pandas-profiling pydantic-settings
# %pip install prettytable
# %pip install pydantic

# %%
from prettytable import PrettyTable
import pandas as pd
import random
import os

# %%
# Load raw_df
raw_data_path = os.path.join('data_lake', 'datasets', 'raw_data', 'challenge_MLE.csv')
raw_df = pd.read_csv(raw_data_path, sep=';')

# Load clean_df
clean_data_path = os.path.join('data_lake', 'datasets', 'cleaned_data', 'cleaned_data.csv')
cleaned_df = pd.read_csv(clean_data_path, index_col=0)

# Load ml_data
ml_data_path = os.path.join('data_lake', 'datasets', 'ml_data', 'ml_data.csv')
ml_df = pd.read_csv(ml_data_path, index_col=0)

# %%
def print_table_schema(df: pd.DataFrame, title=""):
    df_schema = PrettyTable(
        ["Column Name", "Dtype", "Null Values [%]", "Example"], title=title
    )
    for col in df.columns:
        dtype = df.dtypes[col]
        null_values = round(100*df[col].isna().sum()/df.shape[0], 1)
        example_df = df.loc[df[col].notna()]
        example = random.choice(example_df[col].unique())
        df_schema.add_row([col, dtype, null_values, example])

    display(df_schema)
    print('\n\n')


# print_table_schema(raw_df.copy(), title="Raw Data Schema")
# print_table_schema(cleaned_df.copy(), title="Cleaned Data Schema")
# print_table_schema(ml_df.copy(), title="ML Data Schema")

# %%
def filter_data(
    df: pd.DataFrame,
    course_name: str = None,
    user_uuids: list = None,
    course_uuids: list = None,
    particion: int = None,
    pick_random: bool = False
):
    # Filter based on course_name
    if pick_random:
        course_name = random.choice(df['course_name'].unique())

    if course_name is not None:
        df = df.loc[df['course_name'] == course_name]

    # Filter based on user_uuid
    if pick_random:
        user_uuids = list(random.choice(df['user_uuid'].unique()))

    if user_uuids is not None:
        df = df.loc[df['user_uuid'].isin(user_uuids)]

    # Filter based on course_uuids
    if pick_random:
        course_uuids = list(random.choice(df['course_uuid'].unique()))

    if course_uuids is not None:
        df = df.loc[df['course_uuid'].isin(course_uuids)]

    # Filter based on partition
    if pick_random:
        particion = random.choice([p for p in df['particion'].unique() if p > 10])

    if particion is not None:
        df = df.loc[df['particion'] <= particion]
    
    return df

def print_table(
    df: pd.DataFrame, 
    title="", 
    course_name: str = None,
    user_uuids: list = None,
    course_uuids: list = None,
    particion: int = None,
    pick_random: bool = False
):
    df = filter_data(
        df=df,
        course_name=course_name,
        user_uuids=user_uuids,
        course_uuids=course_uuids,
        particion=particion,
        pick_random=pick_random
    )
    pretty_df = PrettyTable(df.columns.tolist(), title=title)
    for row in df.iterrows():
        pretty_df.add_row(row[1].values.tolist())

    display(pretty_df)
    print('\n\n')
    

user_uuids=['13df535e-065c-4593-98ea-5b1e29015b7d']
course_uuids=['09614210-fce2-48bc-93e3-bc4bd441fe00']
particion=44
        
# print_table(
#     raw_df.copy(), 
#     title="Raw Data Example",
#     user_uuids=user_uuids,
#     course_uuids=course_uuids
# )
# print_table(
#     cleaned_df.copy(), 
#     title="Cleaned Data Example",
#     user_uuids=user_uuids,
#     course_uuids=course_uuids
# )
# print_table(
#     ml_df.copy(), 
#     title="ML Data Example",
#     user_uuids=user_uuids,
#     course_uuids=course_uuids
# )

# %%
# %pip install -e .
# Out:
# Obtaining file:///Users/simongarciamorillo/Library/CloudStorage/OneDrive-Personal/Documents/EdMachina/ed-ml
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools==69.0.2 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from ed-ml==1.0.0) (69.0.2)
# Requirement already satisfied: pandas==2.1.3 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from ed-ml==1.0.0) (2.1.3)
# Requirement already satisfied: numpy==1.26.2 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from ed-ml==1.0.0) (1.26.2)
# Requirement already satisfied: scikit-learn==1.3.2 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from ed-ml==1.0.0) (1.3.2)
# Requirement already satisfied: shap==0.43.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from ed-ml==1.0.0) (0.43.0)
# Requirement already satisfied: lightgbm==4.1.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from ed-ml==1.0.0) (4.1.0)
# Requirement already satisfied: xgboost==2.0.2 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from ed-ml==1.0.0) (2.0.2)
# Requirement already satisfied: mlflow==2.8.1 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from ed-ml==1.0.0) (2.8.1)
# Requirement already satisfied: hyperopt==0.2.7 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from ed-ml==1.0.0) (0.2.7)
# Requirement already satisfied: imbalanced-learn==0.11.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from ed-ml==1.0.0) (0.11.0)
# Requirement already satisfied: flask==3.0.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from ed-ml==1.0.0) (3.0.0)
# Requirement already satisfied: pytest==7.4.3 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from ed-ml==1.0.0) (7.4.3)
# Requirement already satisfied: streamlit==1.29.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from ed-ml==1.0.0) (1.29.0)
# Requirement already satisfied: watchdog==3.0.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from ed-ml==1.0.0) (3.0.0)
# Requirement already satisfied: plotly==5.18.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from ed-ml==1.0.0) (5.18.0)
# Requirement already satisfied: openpyxl==3.1.2 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from ed-ml==1.0.0) (3.1.2)
# Requirement already satisfied: psutil==5.9.6 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from ed-ml==1.0.0) (5.9.6)
# Requirement already satisfied: Werkzeug>=3.0.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from flask==3.0.0->ed-ml==1.0.0) (3.0.1)
# Requirement already satisfied: Jinja2>=3.1.2 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from flask==3.0.0->ed-ml==1.0.0) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from flask==3.0.0->ed-ml==1.0.0) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from flask==3.0.0->ed-ml==1.0.0) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from flask==3.0.0->ed-ml==1.0.0) (1.6.2)
# Requirement already satisfied: scipy in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from hyperopt==0.2.7->ed-ml==1.0.0) (1.10.0)
# Requirement already satisfied: six in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from hyperopt==0.2.7->ed-ml==1.0.0) (1.16.0)
# Requirement already satisfied: networkx>=2.2 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from hyperopt==0.2.7->ed-ml==1.0.0) (2.8.4)
# Requirement already satisfied: future in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from hyperopt==0.2.7->ed-ml==1.0.0) (0.18.3)
# Requirement already satisfied: tqdm in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from hyperopt==0.2.7->ed-ml==1.0.0) (4.64.1)
# Requirement already satisfied: cloudpickle in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from hyperopt==0.2.7->ed-ml==1.0.0) (2.0.0)
# Requirement already satisfied: py4j in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from hyperopt==0.2.7->ed-ml==1.0.0) (0.10.9.7)
# Requirement already satisfied: joblib>=1.1.1 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from imbalanced-learn==0.11.0->ed-ml==1.0.0) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from imbalanced-learn==0.11.0->ed-ml==1.0.0) (2.2.0)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from mlflow==2.8.1->ed-ml==1.0.0) (0.17.7)
# Requirement already satisfied: entrypoints<1 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from mlflow==2.8.1->ed-ml==1.0.0) (0.4)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from mlflow==2.8.1->ed-ml==1.0.0) (3.1.40)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from mlflow==2.8.1->ed-ml==1.0.0) (6.0.1)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from mlflow==2.8.1->ed-ml==1.0.0) (3.20.3)
# Requirement already satisfied: pytz<2024 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from mlflow==2.8.1->ed-ml==1.0.0) (2022.7)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from mlflow==2.8.1->ed-ml==1.0.0) (2.31.0)
# Requirement already satisfied: packaging<24 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from mlflow==2.8.1->ed-ml==1.0.0) (22.0)
# Requirement already satisfied: importlib-metadata!=4.7.0,<7,>=3.7.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from mlflow==2.8.1->ed-ml==1.0.0) (4.11.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from mlflow==2.8.1->ed-ml==1.0.0) (0.4.4)
# Requirement already satisfied: alembic!=1.10.0,<2 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from mlflow==2.8.1->ed-ml==1.0.0) (1.11.3)
# Requirement already satisfied: docker<7,>=4.0.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from mlflow==2.8.1->ed-ml==1.0.0) (6.1.3)
# Requirement already satisfied: querystring-parser<2 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from mlflow==2.8.1->ed-ml==1.0.0) (1.2.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from mlflow==2.8.1->ed-ml==1.0.0) (1.4.39)
# Requirement already satisfied: pyarrow<15,>=4.0.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from mlflow==2.8.1->ed-ml==1.0.0) (12.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from mlflow==2.8.1->ed-ml==1.0.0) (3.4.1)
# Requirement already satisfied: matplotlib<4 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from mlflow==2.8.1->ed-ml==1.0.0) (3.7.0)
# Requirement already satisfied: gunicorn<22 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from mlflow==2.8.1->ed-ml==1.0.0) (21.2.0)
# Requirement already satisfied: et-xmlfile in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from openpyxl==3.1.2->ed-ml==1.0.0) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from pandas==2.1.3->ed-ml==1.0.0) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from pandas==2.1.3->ed-ml==1.0.0) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from plotly==5.18.0->ed-ml==1.0.0) (8.2.3)
# Requirement already satisfied: iniconfig in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from pytest==7.4.3->ed-ml==1.0.0) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from pytest==7.4.3->ed-ml==1.0.0) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from pytest==7.4.3->ed-ml==1.0.0) (1.2.0)
# Requirement already satisfied: tomli>=1.0.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from pytest==7.4.3->ed-ml==1.0.0) (2.0.1)
# Requirement already satisfied: slicer==0.0.7 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from shap==0.43.0->ed-ml==1.0.0) (0.0.7)
# Requirement already satisfied: numba in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from shap==0.43.0->ed-ml==1.0.0) (0.58.1)
# Requirement already satisfied: altair<6,>=4.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from streamlit==1.29.0->ed-ml==1.0.0) (4.2.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from streamlit==1.29.0->ed-ml==1.0.0) (5.3.0)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from streamlit==1.29.0->ed-ml==1.0.0) (10.1.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from streamlit==1.29.0->ed-ml==1.0.0) (13.3.5)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from streamlit==1.29.0->ed-ml==1.0.0) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from streamlit==1.29.0->ed-ml==1.0.0) (4.8.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from streamlit==1.29.0->ed-ml==1.0.0) (5.0.1)
# Requirement already satisfied: validators<1,>=0.2 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from streamlit==1.29.0->ed-ml==1.0.0) (0.20.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from streamlit==1.29.0->ed-ml==1.0.0) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from streamlit==1.29.0->ed-ml==1.0.0) (6.1)
# Requirement already satisfied: Mako in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow==2.8.1->ed-ml==1.0.0) (1.2.4)
# Requirement already satisfied: jsonschema>=3.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit==1.29.0->ed-ml==1.0.0) (4.17.3)
# Requirement already satisfied: toolz in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit==1.29.0->ed-ml==1.0.0) (0.12.0)
# Requirement already satisfied: pyjwt>=1.7.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow==2.8.1->ed-ml==1.0.0) (2.4.0)
# Requirement already satisfied: oauthlib>=3.1.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow==2.8.1->ed-ml==1.0.0) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow==2.8.1->ed-ml==1.0.0) (0.8.10)
# Requirement already satisfied: urllib3<2.0.0,>=1.26.7 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from databricks-cli<1,>=0.8.7->mlflow==2.8.1->ed-ml==1.0.0) (1.26.14)
# Requirement already satisfied: websocket-client>=0.32.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from docker<7,>=4.0.0->mlflow==2.8.1->ed-ml==1.0.0) (0.58.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from gitpython<4,>=2.1.0->mlflow==2.8.1->ed-ml==1.0.0) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from importlib-metadata!=4.7.0,<7,>=3.7.0->mlflow==2.8.1->ed-ml==1.0.0) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from Jinja2>=3.1.2->flask==3.0.0->ed-ml==1.0.0) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.8.1->ed-ml==1.0.0) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.8.1->ed-ml==1.0.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.8.1->ed-ml==1.0.0) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.8.1->ed-ml==1.0.0) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.8.1->ed-ml==1.0.0) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow==2.8.1->ed-ml==1.0.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow==2.8.1->ed-ml==1.0.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow==2.8.1->ed-ml==1.0.0) (2023.5.7)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from rich<14,>=10.14.0->streamlit==1.29.0->ed-ml==1.0.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from rich<14,>=10.14.0->streamlit==1.29.0->ed-ml==1.0.0) (2.15.1)
# Requirement already satisfied: decorator>=3.4.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from validators<1,>=0.2->streamlit==1.29.0->ed-ml==1.0.0) (5.1.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from numba->shap==0.43.0->ed-ml==1.0.0) (0.41.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow==2.8.1->ed-ml==1.0.0) (5.0.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.29.0->ed-ml==1.0.0) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.29.0->ed-ml==1.0.0) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/simongarciamorillo/anaconda3/lib/python3.10/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.14.0->streamlit==1.29.0->ed-ml==1.0.0) (0.1.2)
# Installing collected packages: ed-ml
#   Attempting uninstall: ed-ml
#     Found existing installation: ed-ml 1.0.0
#     Uninstalling ed-ml-1.0.0:
#       Successfully uninstalled ed-ml-1.0.0
#   Running setup.py develop for ed-ml
# Successfully installed ed-ml-1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from config.params import Params
from ed_ml.modeling.model_registry import ModelRegistry
from ed_ml.pipeline.pipeline import MLPipeline
from ed_ml.data_processing.feature_engineering import FeatureEngineer
from tqdm import tqdm
import shap
import numpy as np
# Out:
# Initializing Params.
#
# Unable to load base_path.
# Exception: /Users/simongarciamorillo/Library/CloudStorage/OneDrive-Personal/Documents/BetterTradeGroup
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from config.params import Params
#       2 from ed_ml.modeling.model_registry import ModelRegistry
#       3 from ed_ml.pipeline.pipeline import MLPipeline
#
# File ~/Library/CloudStorage/OneDrive-Personal/Documents/BetterTradeGroup/PyTradeX/config/params.py:251
#     249 if not Params.initialized:
#     250     print('Initializing Params.\n')
# --> 251     Params.load()
#
# File ~/Library/CloudStorage/OneDrive-Personal/Documents/BetterTradeGroup/PyTradeX/config/params.py:95, in Params.load(cls)
#      92 # path = os.path.join(os.getcwd(), "PyTradeX", "config", "config.yaml")
#      93 cls.base_cwd = find_base_repo_root()
# ---> 95 with open(os.path.join("config", "config.yml")) as file:
#      96     config: dict = yaml.load(file, Loader=yaml.FullLoader)
#      98 """
#      99 Environment Parameters
#     100 """
#
# FileNotFoundError: [Errno 2] No such file or directory: 'config/config.yml'

# %%
FE = FeatureEngineer(load_dataset=True)

# Instanciate MLPipeline
pipeline = MLPipeline()

# Prepare ML datasets
pipeline.prepare_datasets(
    ml_df=FE.df.copy(),
    train_test_ratio=Params.train_test_ratio
)

# Instanciate ModelRegistry
model_registry = ModelRegistry(
    load_from_local_registry=Params.local_registry
)

model = model_registry.dev_models[0]

explainer = shap.TreeExplainer(model.model)

# Calculate shap values
model.shap_values: np.ndarray = explainer.shap_values(pipeline.X_test)
